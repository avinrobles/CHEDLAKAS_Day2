# %% [markdown]
# ### Install libraries

# %%
# !pip install transformers
# !pip install torch
# !pip install sentencepiece
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 78.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 24.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 67.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 61.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 28.2 MB/s eta 0:00:00
# ...

# %%
#Import libraries
import torch
from transformers import BartTokenizer, BartForConditionalGeneration
from transformers import pipeline

# %% [markdown]
# ###  Load the pre-trained BERT model and tokenizer for summarization

# %%
model_name = "facebook/bart-large-cnn"
tokenizer = BartTokenizer.from_pretrained(model_name)
model = BartForConditionalGeneration.from_pretrained(model_name)

# %% [markdown]
# ### # Create a text summarization pipeline using BERT

# %%
while True:
    # Get user input
    user_input = input("Enter a sentence to summarize (or type '*' to exit): ")

    # Check if the user wants to exit
    if user_input == "*":
        break

    # Tokenize and generate the summary
    inputs = tokenizer(user_input, return_tensors="pt", max_length=1024, truncation=True)
    summary_ids = model.generate(inputs["input_ids"], max_length=150, min_length=30, length_penalty=2.0, num_beams=4, early_stopping=True)

    # Decode and print the summary
    summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
    print("Summary:")
    print(summary)
# Out:
# Enter a sentence to summarize (or type '*' to exit): Meta corporation is owned by Mark Zuckerberg and was renamed two years ago (in 2021)
# Summary:
# Meta corporation is owned by Mark Zuckerberg and was renamed two years ago (in 2021) Mark Zuckerberg is the founder and CEO of the social media giant.
# ...
